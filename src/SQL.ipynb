# %%
#%pip install pymysql

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np

# %% [markdown]
# ### CONEXIÓN A SQL Y CREACIÓN DE BBDD

# %%
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
dfg=pd.read_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\carga_sql\groups.csv')
dfc=pd.read_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\carga_sql\calendar.csv')
dfrf=pd.read_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\carga_sql\fifa_ranking.csv')
dfst=pd.read_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\carga_sql\stadiums.csv')
df_clima=pd.read_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\carga_sql\clima_Doha_acum.csv')

# %%
with open('contraseñas.txt', 'r') as file:
    pass_=file.readlines()[0]

# %%
str_conn=f'mysql+pymysql://root:{pass_}@localhost:3306' #Conectar al servidor
cursor=create_engine(str_conn) #Cursor que apunta al servidor

# %%
cursor.execute('drop database if exists worldcup_qatar_22;')

# %%
cursor.execute('create database worldcup_qatar_22;')

# %%
str_conn=f'mysql+pymysql://root:{pass_}@localhost:3306/worldcup_qatar_22'
cursor=create_engine(str_conn)

# %% [markdown]
# ### CARGA DE DATOS

# %%
dfg.to_sql(name='groups', con=cursor, if_exists='replace', index=False)
dfc.to_sql(name='calendar', con=cursor, if_exists='replace', index=False)
dfrf.to_sql(name='fifa_ranking', con=cursor, if_exists='replace', index=False)
dfst.to_sql(name='stadiums', con=cursor, if_exists='replace', index=False)
df_clima.to_sql(name='clima', con=cursor, if_exists='replace', index=False)

# %%
df_model=pd.read_json(r'C:\Users\david\OneDrive\Documentos\DATA ANALYTICS\PABLO\DATOS FIFA DESCARGADOS-20220720T134943Z-001\DATOS FIFA DESCARGADOS\FIFA_unified_event_data_events.json', lines=True)

# %%
df_model.head()
# Out:
#    match_id  match_run_time_in_ms      match_run_time  match_time_in_ms  \
# 0    129650                     0 2022-11-14 00:00:00                 0
# 1    129650                     0 2022-11-14 00:00:00                 0
# 2    129650                   740 2022-11-14 00:00:00               740
# 3    129650                  1759 2022-11-14 00:00:01              1759
# 4    129650                  1759 2022-11-14 00:00:01              1759
#
#    event_id  player_seq_id  event_order  half_time side           category  \
# 0         1              1            1          1    l      in_possession
# 1         2              1            2          1    l      in_possession
# 2         3              2            1          1    r  out_of_possession
# 3         4              3            1          1    l      in_possession
# 4         5              3            2          1    l      in_possession
#
#         event            event_type action_type  from_player_id  to_player_id  \
# ...

# %%
df_model.to_sql(name='model_match', con=cursor, if_exists='replace', index=False)

# %% [markdown]
# ### SELECCIÓN DE PRIMARY KEYS Y FOREIGN KEYS. CREACIÓN DE RELACIONES ENTRE TABLAS
# Realizado en Workbench. EER Diagram disponible en repositorio.

# %% [markdown]
# ### SQL QUERIES
