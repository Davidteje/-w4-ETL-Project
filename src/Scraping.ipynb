# %%
#%pip install webdriver-manager

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time
import warnings
warnings.filterwarnings('ignore')

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
driver = "./chromedriver.exe" #remember substitute this for your driver path
driver = webdriver.Chrome(driver,options = opciones)

# %%
url = 'https://www.fifa.com/fifa-world-ranking/men?dateId=id13792'

# %%
driver.get(url)

# %%
raw_data = driver.find_elements(By.TAG_NAME, 'table')[0].text.split('\n')[6:]

# %%
lst=[]

for i in range(0, len(raw_data), 4):
    lst.append(raw_data[i:i+4])
    
lst
# Out:
# [['1', 'Brazil', '1841.3', '1837.56 3.74'],
#  ['2', 'Belgium', '1816.71', '1821.92 -5.21'],
#  ['3', 'Argentina', '1773.88', '1770.65 3.23'],
#  ['4', 'France', '1759.78', '1764.85 -5.07'],
#  ['5', 'England', '1728.47', '1737.46 -8.99'],
#  ['6', 'Italy', '1726.14', '1713.86 12.28'],
#  ['7', 'Spain', '1715.22', '1716.93 -1.71'],
#  ['8', 'Netherlands', '1694.51', '1679.41 15.10'],
#  ['9', 'Portugal', '1676.56', '1678.65 -2.09'],
#  ['10', 'Denmark', '1666.57', '1665.47 1.10'],
#  ['11', 'Germany', '1650.21', '1658.96 -8.75'],
#  ['12', 'Croatia', '1645.64', '1632.15 13.49'],
#  ['13', 'Mexico', '1644.89', '1649.57 -4.68'],
#  ['14', 'Uruguay', '1638.71', '1640.95 -2.24'],
#  ['15', 'Switzerland', '1635.92', '1621.43 14.49'],
#  ['16', 'USA', '1627.48', '1635.01 -7.53'],
#  ['17', 'Colombia', '1611.04', '1604.07 6.97'],
#  ['18', 'Senegal', '1584.38', '1584.59 -0.21'],
#  ['19', 'Wales', '1569.82', '1582.13 -12.31'],
#  ['20', 'IR Iran', '1564.61', '1558.64 5.97'],
# ...

# %%
driver.find_elements(By.TAG_NAME, 'img')[0].get_attribute('src')
# Out:
# 'https://digitalhub.fifa.com/transform/d67f1cd3-2a76-49a8-90f0-7b6d65ed7995/FWC_Promo_Qatar_logo_desktop?io=transform:fill,height:110,width:243'

# %%
lista = driver.find_elements(By.TAG_NAME, 'img')

# %%
lst_img = []

for e in lista:
    link = e.get_attribute('src')
    lst_img.append(link)
    
lst_img
# Out:
# ['https://digitalhub.fifa.com/transform/d67f1cd3-2a76-49a8-90f0-7b6d65ed7995/FWC_Promo_Qatar_logo_desktop?io=transform:fill,height:110,width:243',
#  'https://digitalhub.fifa.com/transform/ca40bf37-c80e-413e-9b1a-9a6de6a21e26/FWC_Promo_qatar_logo_mobile?io=transform:fill,height:80,width:177',
#  'https://cloudinary.fifa.com/m/38f59841a983e05b/original/Coke-composite-logo-02-Mens-World-Ranking.png?tx=c_fill,g_auto,q_auto,w_1569,h_456',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/BRA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/BEL?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/ARG?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/FRA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/ENG?tx=c_fill,g_auto,q_auto,w_70,h_46',
# ...

# %%
lst_img = lst_img[3:]
lst_img = lst_img[:-9]
lst_img
# Out:
# ['https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/BRA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/BEL?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/ARG?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/FRA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/ENG?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/ITA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/ESP?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/NED?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/POR?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/DEN?tx=c_fill,g_auto,q_auto,w_70,h_46',
# ...

# %%
acepto=driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]')

acepto.click()

time.sleep(2)   # hace que el codigo se pare aqui 2 segundos

# %%
pag2=driver.find_element(By.XPATH, '//*[@id="content"]/main/section[2]/div/div/div[2]/div/div/div/div/div[2]/div[2]')

pag2.click()

time.sleep(4)   # hace que el codigo se pare aqui 2 segundos
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13212\3987592625.py in <module>
#       1 pag2=driver.find_element(By.XPATH, '//*[@id="content"]/main/section[2]/div/div/div[2]/div/div/div/div/div[2]/div[2]')
#       2
# ----> 3 pag2.click()
#       4
#       5 time.sleep(4)   # hace que el codigo se pare aqui 2 segundos
#
# ~\anaconda3\envs\clase\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      91     def click(self) -> None:
#      92         """Clicks the element."""
# ---> 93         self._execute(Command.CLICK_ELEMENT)
#      94
#      95     def submit(self):
#
# ~\anaconda3\envs\clase\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     408             params = {}
#     409         params["id"] = self._id
# ...

# %% [raw]
# sucio2 = driver.find_element(By.TAG_NAME, 'd-none d-lg-block')
#
# suciop = sucio2.find_elements(By.CLASS_NAME, 'd-block.d-lg-none')
# suciop[8].text

# %% [raw]
# suciop = driver.find_elements(By.TAG_NAME, 'tr')
# suciop[7].text

# %%
sucio2 = driver.find_elements(By.TAG_NAME, 'table')[0].text
sucio2
# Out:
# 'RK\nTeam\nPTS\n+/-\n51\nKSA\n1437.78\n2.04\n52\nGRE\n1437.6\n-3.85\n53\nROU\n1434.68\n6.84\n54\nBFA\n1432.25\n6.61\n55\nSVK\n1425.59\n-14.40\n56\nFIN\n1405.6\n7.19\n57\nVEN\n1404.37\n-0.80\n58\nBIH\n1403.51\n-0.47\n59\nNIR\n1396.55\n-2.55\n60\nPAN\n1393.28\n4.01\n61\nGHA\n1393\n-0.47\n62\nISL\n1384.41\n4.80\n63\nSVN\n1384.04\n11.56\n64\nJAM\n1378.86\n-3.20\n65\nMKD\n1358.51\n-16.69\n66\nALB\n1354.11\n-7.70\n67\nRSA\n1349.59\n-0.96\n68\nIRQ\n1343.01\n4.10\n69\nMNE\n1341.03\n-13.56\n70\nUAE\n1337.57\n-8.52\n71\nCPV\n1336.05\n4.59\n72\nBUL\n1335.36\n10.20\n73\nCOD\n1333.92\n1.08\n74\nSLV\n1330.51\n-2.97\n75\nOMA\n1320.29\n-2.74\n76\nISR\n1316.55\n0.20\n77\nUZB\n1309.98\n3.35\n78\nGEO\n1307.34\n10.88\n79\nCHN\n1305.06\n0.00\n80\nHON\n1301.98\n2.29\n81\nGAB\n1301.84\n0.00\n82\nBOL\n1296.28\n-2.53\n83\nGUI\n1290.47\n-4.42\n84\nJOR\n1289.99\n10.25\n85\nBHR\n1280.64\n-8.61\n86\nCUW\n1278.64\n-14.71\n87\nHAI\n1269.07\n0.00\n88\nZAM\n1267.41\n-3.39\n89\nUGA\n1260.69\n-3.87\n90\nSYR\n1255.92\n
# ...

# %%
raw_data2 = driver.find_elements(By.TAG_NAME, 'table')[0].text.split('\n')[5:]
raw_data2
# Out:
# ['KSA',
#  '1437.78',
#  '2.04',
#  '52',
#  'GRE',
#  '1437.6',
#  '-3.85',
#  '53',
#  'ROU',
#  '1434.68',
#  '6.84',
#  '54',
#  'BFA',
#  '1432.25',
#  '6.61',
#  '55',
#  'SVK',
#  '1425.59',
#  '-14.40',
#  '56',
#  'FIN',
#  '1405.6',
#  '7.19',
#  '57',
#  'VEN',
#  '1404.37',
#  '-0.80',
#  '58',
#  'BIH',
#  '1403.51',
#  '-0.47',
#  '59',
#  'NIR',
#  '1396.55',
#  '-2.55',
#  '60',
#  'PAN',
#  '1393.28',
#  '4.01',
#  '61',
#  'GHA',
#  '1393',
#  '-0.47',
#  '62',
#  'ISL',
#  '1384.41',
#  '4.80',
#  '63',
#  'SVN',
#  '1384.04',
#  '11.56',
#  '64',
#  'JAM',
#  '1378.86',
#  '-3.20',
#  '65',
#  'MKD',
#  '1358.51',
#  '-16.69',
#  '66',
#  'ALB',
#  '1354.11',
#  '-7.70',
#  '67',
#  'RSA',
#  '1349.59',
#  '-0.96',
#  '68',
#  'IRQ',
#  '1343.01',
#  '4.10',
#  '69',
#  'MNE',
#  '1341.03',
#  '-13.56',
#  '70',
#  'UAE',
#  '1337.57',
#  '-8.52',
#  '71',
#  'CPV',
#  '1336.05',
#  '4.59',
#  '72',
#  'BUL',
#  '1335.36',
#  '10.20',
#  '73',
#  'COD',
# ...

# %%
lst2=[]

for i in range(0, len(raw_data2), 4):
    lst2.append(raw_data2[i:i+4])
    
lst2
# Out:
# [['KSA', '1437.78', '2.04', '52'],
#  ['GRE', '1437.6', '-3.85', '53'],
#  ['ROU', '1434.68', '6.84', '54'],
#  ['BFA', '1432.25', '6.61', '55'],
#  ['SVK', '1425.59', '-14.40', '56'],
#  ['FIN', '1405.6', '7.19', '57'],
#  ['VEN', '1404.37', '-0.80', '58'],
#  ['BIH', '1403.51', '-0.47', '59'],
#  ['NIR', '1396.55', '-2.55', '60'],
#  ['PAN', '1393.28', '4.01', '61'],
#  ['GHA', '1393', '-0.47', '62'],
#  ['ISL', '1384.41', '4.80', '63'],
#  ['SVN', '1384.04', '11.56', '64'],
#  ['JAM', '1378.86', '-3.20', '65'],
#  ['MKD', '1358.51', '-16.69', '66'],
#  ['ALB', '1354.11', '-7.70', '67'],
#  ['RSA', '1349.59', '-0.96', '68'],
#  ['IRQ', '1343.01', '4.10', '69'],
#  ['MNE', '1341.03', '-13.56', '70'],
#  ['UAE', '1337.57', '-8.52', '71'],
#  ['CPV', '1336.05', '4.59', '72'],
#  ['BUL', '1335.36', '10.20', '73'],
#  ['COD', '1333.92', '1.08', '74'],
#  ['SLV', '1330.51', '-2.97', '75'],
#  ['OMA', '1320.29', '-2.74', '76'],
#  ['ISR', '1316.55', '0.20', '77'],
# ...

# %%
lista2 = driver.find_elements(By.TAG_NAME, 'img')

# %%
lst_img2 = []

for e in lista2:
    link = e.get_attribute('src')
    lst_img2.append(link)
    
lst_img2
# Out:
# ['https://cloudinary.fifa.com/m/38f59841a983e05b/original/Coke-composite-logo-02-Mens-World-Ranking.png?tx=c_fill,g_auto,q_auto,w_1569,h_456',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/KSA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/GRE?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/ROU?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/BFA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/SVK?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/FIN?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/VEN?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/BIH?tx=c_fill,g_auto,q_auto,w_70,h_46',
# ...

# %%
lst_img2 = lst_img2[1:]
lst_img2 = lst_img2[:-9]
lst_img2
# Out:
# ['https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/KSA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/GRE?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/ROU?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/BFA?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/SVK?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/FIN?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/VEN?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/BIH?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/NIR?tx=c_fill,g_auto,q_auto,w_70,h_46',
#  'https://cloudinary.fifa.com/api/v1/picture/flags-sq-2/PAN?tx=c_fill,g_auto,q_auto,w_70,h_46',
# ...

# %%
#from IPython.display import Image

# %% [raw]
# df = pd.DataFrame()

# %% [raw]
# from IPython.core.display import display,HTML
#
# # your images
# images1 = lst_img
#
# df['imagenes'] = images1
#
#
# # convert your links to html tags
# def path_to_image_html(path):
#     return '<img src="'+ path + '" width="60" >'
#
# pd.set_option('display.max_colwidth', None)
#
# image_cols = ['imagenes']  #<- define which columns will be used to convert to html
#
# # Create the dictionariy to be passed as formatters
# format_dict = {}
# for image_col in image_cols:
#     format_dict[image_col] = path_to_image_html
#
#
# display(HTML(df.to_html(escape=False ,formatters=format_dict)))

# %%
df1 = pd.DataFrame(lst)

# %%
df1
# Out:
#      0                    1        2               3
# 0    1               Brazil   1841.3    1837.56 3.74
# 1    2              Belgium  1816.71   1821.92 -5.21
# 2    3            Argentina  1773.88    1770.65 3.23
# 3    4               France  1759.78   1764.85 -5.07
# 4    5              England  1728.47   1737.46 -8.99
# 5    6                Italy  1726.14   1713.86 12.28
# 6    7                Spain  1715.22   1716.93 -1.71
# 7    8          Netherlands  1694.51   1679.41 15.10
# 8    9             Portugal  1676.56   1678.65 -2.09
# 9   10              Denmark  1666.57    1665.47 1.10
# 10  11              Germany  1650.21   1658.96 -8.75
# 11  12              Croatia  1645.64   1632.15 13.49
# 12  13               Mexico  1644.89   1649.57 -4.68
# 13  14              Uruguay  1638.71   1640.95 -2.24
# 14  15          Switzerland  1635.92   1621.43 14.49
# 15  16                  USA  1627.48   1635.01 -7.53
# 16  17             Colombia  1611.04    1604.07 6.97
# ...

# %%
df1.columns=['RK', 'Team', 'PTS', '+/-']

# %%
type(df1['+/-'][0])
# Out:
# str

# %%
df1.drop(['+/-'], axis=1)
# Out:
#     RK                 Team      PTS
# 0    1               Brazil   1841.3
# 1    2              Belgium  1816.71
# 2    3            Argentina  1773.88
# 3    4               France  1759.78
# 4    5              England  1728.47
# 5    6                Italy  1726.14
# 6    7                Spain  1715.22
# 7    8          Netherlands  1694.51
# 8    9             Portugal  1676.56
# 9   10              Denmark  1666.57
# 10  11              Germany  1650.21
# 11  12              Croatia  1645.64
# 12  13               Mexico  1644.89
# 13  14              Uruguay  1638.71
# 14  15          Switzerland  1635.92
# 15  16                  USA  1627.48
# 16  17             Colombia  1611.04
# 17  18              Senegal  1584.38
# 18  19                Wales  1569.82
# 19  20              IR Iran  1564.61
# 20  21               Serbia  1563.62
# 21  22              Morocco   1563.5
# 22  23                 Peru  1561.01
# 23  24                Japan  1559.54
# ...

# %%
# EXPORTACION 
#df1.to_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\ficheros_de_trabajo\tabla_top50.csv', index=False)

# %%
lst2[:10]
# Out:
# [['KSA', '1437.78', '2.04', '52'],
#  ['GRE', '1437.6', '-3.85', '53'],
#  ['ROU', '1434.68', '6.84', '54'],
#  ['BFA', '1432.25', '6.61', '55'],
#  ['SVK', '1425.59', '-14.40', '56'],
#  ['FIN', '1405.6', '7.19', '57'],
#  ['VEN', '1404.37', '-0.80', '58'],
#  ['BIH', '1403.51', '-0.47', '59'],
#  ['NIR', '1396.55', '-2.55', '60'],
#  ['PAN', '1393.28', '4.01', '61']]

# %%
df2 = pd.DataFrame(lst2)
df2
# Out:
#       0        1       2     3
# 0   KSA  1437.78    2.04    52
# 1   GRE   1437.6   -3.85    53
# 2   ROU  1434.68    6.84    54
# 3   BFA  1432.25    6.61    55
# 4   SVK  1425.59  -14.40    56
# 5   FIN   1405.6    7.19    57
# 6   VEN  1404.37   -0.80    58
# 7   BIH  1403.51   -0.47    59
# 8   NIR  1396.55   -2.55    60
# 9   PAN  1393.28    4.01    61
# 10  GHA     1393   -0.47    62
# 11  ISL  1384.41    4.80    63
# 12  SVN  1384.04   11.56    64
# 13  JAM  1378.86   -3.20    65
# 14  MKD  1358.51  -16.69    66
# 15  ALB  1354.11   -7.70    67
# 16  RSA  1349.59   -0.96    68
# 17  IRQ  1343.01    4.10    69
# 18  MNE  1341.03  -13.56    70
# 19  UAE  1337.57   -8.52    71
# 20  CPV  1336.05    4.59    72
# 21  BUL  1335.36   10.20    73
# 22  COD  1333.92    1.08    74
# 23  SLV  1330.51   -2.97    75
# 24  OMA  1320.29   -2.74    76
# 25  ISR  1316.55    0.20    77
# 26  UZB  1309.98    3.35    78
# 27  GEO  1307.34   10.88    79
# 28  CHN  1305.06    0.00    80
# ...

# %%
df2.columns=['Team', 'PTS', '+/-', 'RK']
df2
# Out:
#    Team      PTS     +/-    RK
# 0   KSA  1437.78    2.04    52
# 1   GRE   1437.6   -3.85    53
# 2   ROU  1434.68    6.84    54
# 3   BFA  1432.25    6.61    55
# 4   SVK  1425.59  -14.40    56
# 5   FIN   1405.6    7.19    57
# 6   VEN  1404.37   -0.80    58
# 7   BIH  1403.51   -0.47    59
# 8   NIR  1396.55   -2.55    60
# 9   PAN  1393.28    4.01    61
# 10  GHA     1393   -0.47    62
# 11  ISL  1384.41    4.80    63
# 12  SVN  1384.04   11.56    64
# 13  JAM  1378.86   -3.20    65
# 14  MKD  1358.51  -16.69    66
# 15  ALB  1354.11   -7.70    67
# 16  RSA  1349.59   -0.96    68
# 17  IRQ  1343.01    4.10    69
# 18  MNE  1341.03  -13.56    70
# 19  UAE  1337.57   -8.52    71
# 20  CPV  1336.05    4.59    72
# 21  BUL  1335.36   10.20    73
# 22  COD  1333.92    1.08    74
# 23  SLV  1330.51   -2.97    75
# 24  OMA  1320.29   -2.74    76
# 25  ISR  1316.55    0.20    77
# 26  UZB  1309.98    3.35    78
# 27  GEO  1307.34   10.88    79
# 28  CHN  1305.06    0.00    80
# ...

# %%
df2 = df2[['RK','Team','PTS','+/-']]
df2
# Out:
#       RK Team      PTS     +/-
# 0     52  KSA  1437.78    2.04
# 1     53  GRE   1437.6   -3.85
# 2     54  ROU  1434.68    6.84
# 3     55  BFA  1432.25    6.61
# 4     56  SVK  1425.59  -14.40
# 5     57  FIN   1405.6    7.19
# 6     58  VEN  1404.37   -0.80
# 7     59  BIH  1403.51   -0.47
# 8     60  NIR  1396.55   -2.55
# 9     61  PAN  1393.28    4.01
# 10    62  GHA     1393   -0.47
# 11    63  ISL  1384.41    4.80
# 12    64  SVN  1384.04   11.56
# 13    65  JAM  1378.86   -3.20
# 14    66  MKD  1358.51  -16.69
# 15    67  ALB  1354.11   -7.70
# 16    68  RSA  1349.59   -0.96
# 17    69  IRQ  1343.01    4.10
# 18    70  MNE  1341.03  -13.56
# 19    71  UAE  1337.57   -8.52
# 20    72  CPV  1336.05    4.59
# 21    73  BUL  1335.36   10.20
# 22    74  COD  1333.92    1.08
# 23    75  SLV  1330.51   -2.97
# 24    76  OMA  1320.29   -2.74
# 25    77  ISR  1316.55    0.20
# 26    78  UZB  1309.98    3.35
# 27    79  GEO  1307.34   10.88
# 28    80  CHN  1305.06    0.00
# ...

# %%
df2.RK[1:] = df2.RK[:-1]

# %%
df2.RK[0] = 51

# %%
df2
# Out:
#      RK Team      PTS     +/-
# 0    51  KSA  1437.78    2.04
# 1    52  GRE   1437.6   -3.85
# 2    53  ROU  1434.68    6.84
# 3    54  BFA  1432.25    6.61
# 4    55  SVK  1425.59  -14.40
# 5    56  FIN   1405.6    7.19
# 6    57  VEN  1404.37   -0.80
# 7    58  BIH  1403.51   -0.47
# 8    59  NIR  1396.55   -2.55
# 9    60  PAN  1393.28    4.01
# 10   61  GHA     1393   -0.47
# 11   62  ISL  1384.41    4.80
# 12   63  SVN  1384.04   11.56
# 13   64  JAM  1378.86   -3.20
# 14   65  MKD  1358.51  -16.69
# 15   66  ALB  1354.11   -7.70
# 16   67  RSA  1349.59   -0.96
# 17   68  IRQ  1343.01    4.10
# 18   69  MNE  1341.03  -13.56
# 19   70  UAE  1337.57   -8.52
# 20   71  CPV  1336.05    4.59
# 21   72  BUL  1335.36   10.20
# 22   73  COD  1333.92    1.08
# 23   74  SLV  1330.51   -2.97
# 24   75  OMA  1320.29   -2.74
# 25   76  ISR  1316.55    0.20
# 26   77  UZB  1309.98    3.35
# 27   78  GEO  1307.34   10.88
# 28   79  CHN  1305.06    0.00
# 29   80  HON  1301.98    2.29
# ...

# %%
df2.drop(['+/-'], axis=1)
# Out:
#      RK Team      PTS
# 0    51  KSA  1437.78
# 1    52  GRE   1437.6
# 2    53  ROU  1434.68
# 3    54  BFA  1432.25
# 4    55  SVK  1425.59
# 5    56  FIN   1405.6
# 6    57  VEN  1404.37
# 7    58  BIH  1403.51
# 8    59  NIR  1396.55
# 9    60  PAN  1393.28
# 10   61  GHA     1393
# 11   62  ISL  1384.41
# 12   63  SVN  1384.04
# 13   64  JAM  1378.86
# 14   65  MKD  1358.51
# 15   66  ALB  1354.11
# 16   67  RSA  1349.59
# 17   68  IRQ  1343.01
# 18   69  MNE  1341.03
# 19   70  UAE  1337.57
# 20   71  CPV  1336.05
# 21   72  BUL  1335.36
# 22   73  COD  1333.92
# 23   74  SLV  1330.51
# 24   75  OMA  1320.29
# 25   76  ISR  1316.55
# 26   77  UZB  1309.98
# 27   78  GEO  1307.34
# 28   79  CHN  1305.06
# 29   80  HON  1301.98
# 30   81  GAB  1301.84
# 31   82  BOL  1296.28
# 32   83  GUI  1290.47
# 33   84  JOR  1289.99
# 34   85  BHR  1280.64
# 35   86  CUW  1278.64
# 36   87  HAI  1269.07
# 37   88  ZAM  1267.41
# 38   89  UGA  1260.69
# 39   90  SYR  1255.92
# ...

# %%
#df2.to_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\ficheros_de_trabajo\tabla_top50_100.csv', index=False)

# %%
df3 = pd.DataFrame(lst_img)

# %%
df4 = pd.DataFrame(lst_img2)

# %%
#df3.to_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\ficheros_de_trabajo\link_pic_top50.csv', index=False)

# %%
#df4.to_csv(r'C:\Users\david\Proyectos\Local\-w4-ETL-Project\ficheros_de_trabajo\link_pic_top50_70.csv', index=False)
